# %%
import requests
import re

# %%
url = "https://www.onlinecourses24x7.com/"
headers = {"User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/70.0.3538.77 Safari/537.36"}

# %%
r = requests.get(url, headers = headers)

# %%
text = r.text

# %%
from bs4 import BeautifulSoup
soup = BeautifulSoup(text, 'html.parser')

# %%
soup
# Out:
# <!DOCTYPE html>
# ...

# %% [markdown]
# # class

# %%
h2s = soup.find_all('h2', class_='entry-title')

# %%
for h2 in h2s:
    print(h2.text)
# Out:
#  [Udemy 100% Off]-Professional Real Estate Investing
#  [Udemy 100% Off]-Arabic Alphabet For Beginners
#  [Udemy 100% Off]-Job Descriptions
#  [Udemy 100% Off]-Conflict Resolution in Investor Relations
#  [Udemy 100% Off]-Employee to Consultant – E2C MASTERCLASS
#  [Udemy 100% Off]-Sociology: Understanding our society
#  [Udemy 100% Off]-Azure DP-900 Practice Test Prep Exam
#  [Udemy 100% Off]-Artificial Intelligence Music Creation (2021 Edition)
#  [Udemy 100% Off]-DP-300 Practice Test Prep Exam
#  [Udemy 100% Off]-MB-330 Microsoft Dynamics 365 Supply Chain Management- Test

# %%
for h2 in h2s:
    print(h2.a['href'])
# Out:
# https://www.onlinecourses24x7.com/udemy-100-off-professional-real-estate-investing/
# https://www.onlinecourses24x7.com/udemy-100-off-arabic-alphabet-for-beginners/
# https://www.onlinecourses24x7.com/udemy-100-off-job-descriptions/
# https://www.onlinecourses24x7.com/udemy-100-off-conflict-resolution-in-investor-relations/
# https://www.onlinecourses24x7.com/udemy-100-off-employee-to-consultant-e2c-masterclass/
# https://www.onlinecourses24x7.com/udemy-100-off-sociology-understanding-our-society/
# https://www.onlinecourses24x7.com/udemy-100-off-azure-dp-900-practice-test-prep-exam/
# https://www.onlinecourses24x7.com/udemy-100-off-artificial-intelligence-music-creation-2021-edition/
# https://www.onlinecourses24x7.com/udemy-100-off-dp-300-practice-test-prep-exam/
# https://www.onlinecourses24x7.com/udemy-100-off-mb-330-microsoft-dynamics-365-supply-chain-management-test/

# %%
time = soup.find_all('time', class_='entry-date published')

# %%
time
# Out:
# [<time class="entry-date published" datetime="2021-08-25T05:45:27+00:00">August 25, 2021</time>,
#  <time class="entry-date published" datetime="2021-08-25T05:44:43+00:00">August 25, 2021</time>,
#  <time class="entry-date published" datetime="2021-08-25T05:44:08+00:00">August 25, 2021</time>,
#  <time class="entry-date published" datetime="2021-08-25T05:16:10+00:00">August 25, 2021</time>,
#  <time class="entry-date published" datetime="2021-08-25T05:15:14+00:00">August 25, 2021</time>,
#  <time class="entry-date published" datetime="2021-08-25T04:56:48+00:00">August 25, 2021</time>,
#  <time class="entry-date published" datetime="2021-08-24T07:16:03+00:00">August 24, 2021</time>,
#  <time class="entry-date published" datetime="2021-08-24T06:45:40+00:00">August 24, 2021</time>,
#  <time class="entry-date published" datetime="2021-08-24T06:39:08+00:00">August 24, 2021</time>,
#  <time class="entry-date published" datetime="2021-08-24T06:09:10+00:00">August 24, 2021</time>]

# %%
class_url = "https://www.onlinecourses24x7.com/udemy-100-off-professional-real-estate-investing/"

# %%
r = requests.get(class_url, headers = headers)

# %%
soup = BeautifulSoup(r.text, "html.parser")

# %%
div = soup.find('div', class_='su-button-center')

# %%
div.a['href']
# Out:
# 'https://click.linksynergy.com/deeplink?id=KLRB8G/RnDE&mid=39197&u1=vini&murl=https%3A%2F%2Fwww.udemy.com%2Fcourse%2Fprofessional-real-estate-investing%2F%3FcouponCode%3DA60BA5127EDD6F8BDACC'

# %%
<time class="entry-date published" datetime="2021-08-25T05:45:27+00:00">August 25, 2021</time>

# %%
time = soup.find('time', class_='entry-date published')

# %%
time['datetime']
# Out:
# '2021-08-25T05:45:27+00:00'

# %%
pre = soup.find('li', class_='previous')

# %%
pre.a['href']
# Out:
# 'https://www.onlinecourses24x7.com/udemy-100-off-arabic-alphabet-for-beginners/'

# %%
request.get('https://www.onlinecourses24x7.com/')

# %%
class UDEMY_URL:
	main_path = "https://www.onlinecourses24x7.com/"

headers = {"User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/70.0.3538.77 Safari/537.36"}

# %%
import requests
from bs4 import BeautifulSoup

r = requests.get(UDEMY_URL.main_path, headers = headers)
soup = BeautifulSoup(r.text, 'html.parser')
h2s = soup.find_all('h2', class_='entry-title')
titles = [h2.text for h2 in h2s]
print(titles)
hrefs = [h2.a['href'] for h2 in h2s]
print(hrefs)
pub_dates = soup.find_all('time', class_='entry-date published')
pub_dates = [pub_date['datetime'] for pub_date in pub_dates]
print(pub_dates)
list_uedmy_free_urls = []

for title, href, pub_date in zip(titles, hrefs, pub_dates):
    r = requests.get(href, headers = headers, timeout=10)
    soup = BeautifulSoup(r.text, 'html.parser')
    udemy_free_url = soup.find('div', class_='su-button-center').a['href']
    print(udemy_free_url)
    pub_date = soup.find('time', class_='entry-date published')
    print(pub_date)
    list_uedmy_free_urls.append({'title':title,
                                 'pub_date':pub_date,
                                 'url':udemy_free_url})
    print('='*30)
# Out:
# [' [Udemy 100% Off]-Professional Real Estate Investing', ' [Udemy 100% Off]-Arabic Alphabet For Beginners', ' [Udemy 100% Off]-Job Descriptions', ' [Udemy 100% Off]-Conflict Resolution in Investor Relations', ' [Udemy 100% Off]-Employee to Consultant – E2C MASTERCLASS', ' [Udemy 100% Off]-Sociology: Understanding our society', ' [Udemy 100% Off]-Azure DP-900 Practice Test Prep Exam', ' [Udemy 100% Off]-Artificial Intelligence Music Creation (2021 Edition)', ' [Udemy 100% Off]-DP-300 Practice Test Prep Exam', ' [Udemy 100% Off]-MB-330 Microsoft Dynamics 365 Supply Chain Management- Test']
# ...
