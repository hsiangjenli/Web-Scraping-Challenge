# %%
from TWSE.twserevise import TWSE

# period = ('2022-01-11', '2022-03-01')
period = ('2022-03-11', '2022-03-20')
twse = TWSE(period=period)

# %%
for df in twse.crawlerDailyQuotes():
    print(df)
# Out:
# https://www.twse.com.tw/exchangeReport/MI_INDEX?response=json&date=20210811&type=ALL
#          證券代號     證券名稱       成交股數    成交筆數  ...  最後揭示買量  最後揭示賣價 最後揭示賣量    本益比
# 0        50.0   元大台灣50  3867154.0  7131.0  ...    21.0  137.25   70.0   0.00
# 1        51.0  元大中型100    77833.0   138.0  ...     4.0    57.1   17.0   0.00
# 2        52.0     富邦科技   736191.0   309.0  ...     5.0   124.4    1.0   0.00
# 3        53.0     元大電子    14500.0    14.0  ...     1.0   66.45    1.0   0.00
# 4        54.0   元大台商50     3010.0     4.0  ...    26.0    31.9    8.0   0.00
# ...       ...      ...        ...     ...  ...     ...     ...    ...    ...
# 22719  9944.0       新麗   209583.0   100.0  ...     5.0    21.6    1.0  29.19
# 22720  9945.0      潤泰新  6743695.0  3955.0  ...    69.0    65.3   65.0   8.01
# 22721  9946.0     三發地產   465364.0   121.0  ...    15.0   15.95   17.0  99.38
# 22722  9955.0       佳龍   174901.0   239.0  ...     7.0   17.25    3.0   0.00
# ...

# %%
for df in twse.crawlerEvery5SecondsIndex():
    print(df)
# Out:
#             時間  發行量加權股價指數  未含金融保險股指數   未含電子股指數  未含金融電子股指數   水泥類指數    食品類指數  \
# 0     09:00:00   17433.20   15066.83  19987.57   16788.18  186.20  1881.70
# 1     09:00:05   17373.82   15009.18  19952.26   16747.34  186.20  1882.91
# 2     09:00:10   17369.92   15006.36  19947.76   16745.52  186.22  1882.20
# 3     09:00:15   17352.31   14993.27  19930.42   16739.65  186.22  1879.23
# 4     09:00:20   17347.91   14992.20  19927.63   16748.00  185.72  1879.09
# ...        ...        ...        ...       ...        ...     ...      ...
# 3236  13:29:40   17253.01   14904.61  19888.55   16719.90  185.97  1872.02
# 3237  13:29:45   17253.01   14904.61  19888.55   16719.90  185.97  1872.02
# 3238  13:29:50   17253.01   14904.61  19888.55   16719.90  185.97  1872.02
# 3239  13:29:55   17253.01   14904.61  19888.55   16719.90  185.97  1872.02
# 3240  13:30:00   17264.74   14914.61  19900.64   16729.07  186.04  1876.89
#
# ...

# %%
df
# Out:
#             時間  發行量加權股價指數  未含金融保險股指數   未含電子股指數  未含金融電子股指數   水泥類指數    食品類指數  \
# 0     09:00:00   17433.20   15066.83  19987.57   16788.18  186.20  1881.70
# 1     09:00:05   17373.82   15009.18  19952.26   16747.34  186.20  1882.91
# 2     09:00:10   17369.92   15006.36  19947.76   16745.52  186.22  1882.20
# 3     09:00:15   17352.31   14993.27  19930.42   16739.65  186.22  1879.23
# 4     09:00:20   17347.91   14992.20  19927.63   16748.00  185.72  1879.09
# ...        ...        ...        ...       ...        ...     ...      ...
# 3236  13:29:40   17253.01   14904.61  19888.55   16719.90  185.97  1872.02
# 3237  13:29:45   17253.01   14904.61  19888.55   16719.90  185.97  1872.02
# 3238  13:29:50   17253.01   14904.61  19888.55   16719.90  185.97  1872.02
# 3239  13:29:55   17253.01   14904.61  19888.55   16719.90  185.97  1872.02
# 3240  13:30:00   17264.74   14914.61  19900.64   16729.07  186.04  1876.89
#
# ...

# %%
for df in twse.crawlerTaiwanWeightedIndex():
    print(df)
# Out:
#             日期          成交股數          成交金額       成交筆數  發行量加權股價指數    漲跌點數
# 0   2021-08-02  8.433836e+09  4.401895e+11  2581704.0   17503.28  255.87
# 1   2021-08-03  7.297083e+09  3.903000e+11  2300155.0   17553.76   50.48
# 2   2021-08-04  8.674007e+09  3.790903e+11  2535997.0   17623.89   70.13
# 3   2021-08-05  9.310148e+09  3.859234e+11  2803525.0   17603.12  -20.77
# 4   2021-08-06  8.507807e+09  4.012576e+11  2764690.0   17526.28  -76.84
# 5   2021-08-09  7.894068e+09  3.524025e+11  2493714.0   17485.15  -41.13
# 6   2021-08-10  7.424102e+09  3.529958e+11  2356807.0   17323.64 -161.51
# 7   2021-08-11  8.485348e+09  3.922855e+11  2702640.0   17227.18  -96.46
# 8   2021-08-12  6.583769e+09  3.225433e+11  2063506.0   17219.94   -7.24
# 9   2021-08-13  8.080388e+09  3.866391e+11  2570094.0   16982.11 -237.83
# 10  2021-08-16  7.549788e+09  3.361928e+11  2412039.0   16858.77 -123.34
# 11  2021-08-17  6.572397e+09  2.997686e+11  2172972.0   16661.36 -197.41
# ...

# %%
import os

path = r"D:\Python\NKUST-1102-Django-POA-Midterm-Project\app__home_page\dataset\twii.csv"

for df in twse.crawlerTotalIndexHistoricalData():
    df.rename(columns={
        '日期':'Date',
        '開盤指數': 'O',
        '最高指數': 'H',
        '最低指數': 'L',
        '收盤指數': 'C'
    }, inplace=True)
    if os.path.exists(path):
        df.to_csv(path, mode='a', header=False, index=None)
    else:
        df.to_csv(path, index=None)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_17672/835139081.py in <module>
#       3 path = r"D:\Python\NKUST-1102-Django-POA-Midterm-Project\app__home_page\dataset\twii.csv"
#       4
# ----> 5 for df in twse.crawlerTotalIndexHistoricalData():
#       6     df.rename(columns={
#       7         '日期':'Date',
#
# d:\Python\Web-Scraping-Challenge\TWSE｜台灣證券交易所\TWSE\twserevise.py in crawlerTotalIndexHistoricalData(self)
#     164                 url = TWSE.url.TotalIndexHistoricalData.format(date=TDate.date.toStringNospace(start))
#     165                 self.crawlerJson(url)
# --> 166                 df = Clean.to_df(self.raw)
#     167                 yield df
#     168                 time.sleep(self.sleep)
#
# d:\Python\Web-Scraping-Challenge\TWSE｜台灣證券交易所\TWSE\Clean.py in to_df(data, stock_code)
#       4     '''將json轉換成DataFrame'''
# ...
